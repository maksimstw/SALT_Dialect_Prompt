# %%
import os
import openai
import pandas as pd

from tqdm import tqdm

# %%
openai.api_key = "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"

# %%
df = pd.read_csv('gpt3_dataset.csv')
df
# Out:
#                                                history  \
# 0    Complete the following conversation.\nA: So he...
# 1    Complete the following conversation.\nA: Katar...
# 2    Complete the following conversation.\nA: How f...
# 3    Complete the following conversation.\nA: May I...
# 4    Complete the following conversation.\nA: I cam...
# ..                                                 ...
# 967  Complete the following conversation.\nA: Oh! O...
# 968  Complete the following conversation.\nA: Now l...
# 969  Complete the following conversation.\nA: Sphin...
# 970  Complete the following conversation.\nA: To us...
# 971  Complete the following conversation.\nA: Corre...
#
#                                            groundtruth  \
# 0                That's never been proven<|endoftext|>
# 1    I still maintain that he kicked himself in the...
# 2    I am afraid this is not the worst news.<|endof...
# 3                                A woman?<|endoftext|>
# ...

# %%
gen_aave = []
gen_sae = []

for sae, aave in tqdm(zip(df['history'], df['history_aave']), total=len(df)):   
    response = openai.Completion.create(
    engine="text-davinci-002",
    prompt=sae,
    temperature=0.7,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
    )
    gen_sae.append(response["choices"][0]["text"])
    response = openai.Completion.create(
    engine="text-davinci-002",
    prompt=aave,
    temperature=0.7,
    max_tokens=512,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
    )
    gen_aave.append(response["choices"][0]["text"])

df['gen_sae'] = gen_sae
df['gen_aave'] = gen_aave
# Out:
# 100%|██████████| 972/972 [58:00<00:00,  3.58s/it]

# %%
df.to_csv('gpt3_cornell_movie.csv', index=False)
