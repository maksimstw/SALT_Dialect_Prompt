# %%
from datasets import load_dataset
from transformers import AutoTokenizer, BlenderbotTokenizer
from tqdm import tqdm
from ast import literal_eval

import pandas as pd
import csv
import re
import torch

device = 'cuda' if torch.cuda.is_available else 'cpu'

# %%
tokenizer = AutoTokenizer.from_pretrained("microsoft/DialoGPT-large")

# %% [markdown]
# ## GPT-3

# %%
df = pd.read_csv('runs/21/dataset/dialogpt/all/cornell_movie_dataset_all.csv')

# %%
newdf = df[df['num_aave_fts'] >= 6]

# %%
newdf = newdf.reset_index(drop=True)

# %%
def split_turns(s):
    turns = s.split('<|endoftext|>')
    if len(turns) < 3:
        return None
    result = 'Complete the following conversation.\n'
    result += 'A: ' + turns[0] + '\n'
    result += 'B: ' + turns[1] + '\n'
    result += 'A: ' + turns[2] + '\n'
    result += 'B:'
    return result

# %%
newdf['history'] = newdf['history'].apply(split_turns)
newdf['history_aave'] = newdf['history_aave'].apply(split_turns)

# %%
newdf = newdf.dropna()
newdf = newdf.reset_index(drop=True)

# %%
newdf.to_csv('gpt3_dataset.csv', index=False)

# %% [markdown]
# ## DailyDialog

# %%
dataset = load_dataset('daily_dialog')
# Out:
# Using custom data configuration default
# Reusing dataset daily_dialog (C:\Users\stwan\.cache\huggingface\datasets\daily_dialog\default\1.0.0\c03444008e9508b8b76f1f6793742d37d5e5f83364f8d573c2747bff435ea55c)
# 100%|██████████| 3/3 [00:00<00:00, 600.04it/s]

# %%
print(len(dataset['train']['dialog']))
# Out:
# 11118

# %%
for i in tqdm(range(1)):
    dialog = dataset['train']['dialog'][i]
    txt = ''
    if len(dialog) > 3:
        for u in dialog[:-1]:
            txt += u + tokenizer.eos_token
    print(txt)
# Out:
#   9%|▉         | 2/22 [00:00<00:01, 11.12it/s]
# Say , Jim , how about going for a few beers after dinner ? <|endoftext|> You know that is tempting but is really not good for our fitness . <|endoftext|> What do you mean ? It will help us to relax . <|endoftext|> Do you really think so ? I don't . It will just make us fat and act silly . Remember last time ? <|endoftext|> I guess you are right.But what shall we do ? I don't feel like sitting at home . <|endoftext|> I suggest a walk over to the gym where we can play singsong and meet some of our friends . <|endoftext|> That's a good idea . I hear Mary and Sally often go there to play pingpong.Perhaps we can make a foursome with them . <|endoftext|> Sounds great to me ! If they are willing , we could ask them to go dancing with us.That is excellent exercise and fun , too . <|endoftext|> Good.Let ' s go now . <|endoftext|>
# Can you do push-ups ? <|endoftext|> Of course I can . It's a piece of cake ! Believe it or not , I can do 30 push-ups a minute . <|endoftext|> Really ? I think that's impossible ! <|endoftext|> You mean 30 push-ups ? <|endoftext|> Yeah ! <|endoftext|>
# Can you study with the radio on ? <|endoftext|> No , I listen to background music . <|endoftext|> What is the difference ? <|endoftext|> The radio has too many comerials . <|endoftext|>
#  27%|██▋       | 6/22 [00:00<00:01, 11.23it/s]
# Are you all right ? <|endoftext|> I will be all right soon . I was terrified when I watched them fall from the wire . <|endoftext|> Don't worry.He is an acrobat 。 <|endoftext|>
# Hey John , nice skates . Are they new ? <|endoftext|> Yeah , I just got them . I started playing ice hockey in a community league . So , I finally got myself new skates . <|endoftext|> What position do you play ? <|endoftext|> I ’ m a defender . It ’ s a lot of fun . You don ’ t have to be able to skate as fast on defense . <|endoftext|> Yeah , you ’ re a pretty big guy . I play goalie , myself . <|endoftext|> Oh , yeah ? Which team ? <|endoftext|> The Rockets . <|endoftext|> Really ? I think we play you guys next week . Well , I have to go to practice . See you later . <|endoftext|>
# Hey Lydia , what are you reading ? <|endoftext|> I ’ m looking at my horoscope for this month ! My outlook is very positive . It says that I should take a vacation to someplace exotic , and that I will have a passionate summer fling ! <|endoftext|> What are you talking about ? Let me see that ... What are horoscopes ? <|endoftext|> It ’ s a prediction of your month , based on your zodiac sign . You have a different sign for the month and date you were born in . I was born on April 15th , so I ’ m an Aries . When were you born ? <|endoftext|> January 5th . <|endoftext|> Let ’ s see . . . you ’ re a Capricorn . It says that you will be feeling stress at work , but you could see new , exciting developments in your love life . Looks like we ’ ll both have interesting summers ! <|endoftext|> That ’ s bogus . I don't feel any stress at work , and my love life is practically nonexistent . This zodiac stuff is all a bunch of nonsense . <|endoftext|> No , it ’ s not , your astrology sign can tell you a lot about your personality . See ? It says that an Aries is energetic and loves to socialize . <|endoftext|> Well , you certainly match those criteria , but they ’ re so broad they could apply to anyone . What does it say about me ? <|endoftext|>
# Frank ’ s getting married , do you believe this ? <|endoftext|> Is he really ? <|endoftext|> Yes , he is . He loves the girl very much . <|endoftext|> Who is he marring ? <|endoftext|> A girl he met on holiday in Spain , I think . <|endoftext|> Have they set a date for the wedding ? <|endoftext|>
#  36%|███▋      | 8/22 [00:00<00:01, 10.03it/s]
# I hear you bought a new house in the northern suburbs . <|endoftext|> That ’ s right , we bought it the same day we came on the market . <|endoftext|> What kind of house is it ? <|endoftext|> It ’ s a wonderful Spanish style . <|endoftext|> Oh , I love the roof tiles on Spanish style houses . <|endoftext|> And it ’ s a bargaining . A house like this in river side costs double the price . <|endoftext|> Great , is it a two bedroom house ? <|endoftext|> No , it has three bedrooms and three beds , and has a living room with a twelve-foot ceiling . There ’ s a two-car garage . <|endoftext|> That ’ s a nice area too . It ’ ll be a good investment for you . <|endoftext|> Yeas , when will you buy a house ? <|endoftext|> Not untill the end of this year , you know , just before my wedding . <|endoftext|> Right , congratulations . <|endoftext|>
# Hi , Becky , what's up ? <|endoftext|> Not much , except that my mother-in-law is driving me up the wall . <|endoftext|> What's the problem ? <|endoftext|> She loves to nit-pick and criticizes everything that I do . I can never do anything right when she's around . <|endoftext|> For example ? <|endoftext|> Well , last week I invited her over to dinner . My husband and I had no problem with the food , but if you listened to her , then it would seem like I fed her old meat and rotten vegetables . There's just nothing can please her . <|endoftext|> No , I can't see that happening . I know you're a good cook and nothing like that would ever happen . <|endoftext|> It's not just that . She also criticizes how we raise the kids . <|endoftext|> My mother-in-law used to do the same thing to us . If it wasn't disciplining them enough , then we were disciplining them too much . She also complained about the food we fed them , the schools we sent them too , and everything else under the sun . <|endoftext|> You said she used to ? How did you stop her ? <|endoftext|> We basically sat her down and told her how we felt about her constant criticizing , and how we welcomed her advice but hoped she'd let us do our things . She understood , and now everything is a lot more peaceful . <|endoftext|>
#  55%|█████▍    | 12/22 [00:01<00:01,  9.85it/s]
# How are Zina's new programmers working out ? <|endoftext|> I hate to admit it , but they're good . And fast . The Filipino kid is a genius . <|endoftext|> So you'll make the Stars.com deadline , and have us up and running next week ? <|endoftext|> It'll be close , but we'll make it . <|endoftext|> Good . After Stars.com starts paying us , we won't need Vikam's cash anymore . <|endoftext|>
# Do you like cooking ? <|endoftext|> Yes . I like cooking very much . I got this hobby when I was 12 years sold . <|endoftext|> Why do you like it ? <|endoftext|> I have no idea . I like cooking by myself . I like to taste delicious food . <|endoftext|> That's wonderful ! <|endoftext|> And I love trying new recipes , which I usually test with my friends . You can come , too . <|endoftext|> Really ? I hope I can have a chance to taste it . Don't forget to tell me . <|endoftext|>
# Anyone home ? Jen ! <|endoftext|> I'm in the kitchen ... let yourself in ! <|endoftext|> Wow ! You're really working up a storm ! <|endoftext|> I know . I've even worked up a sweat . <|endoftext|>
#  64%|██████▎   | 14/22 [00:01<00:00, 10.23it/s]
# You look so tan and healthy ! <|endoftext|> Thanks . I just got back from summer camp . <|endoftext|> How was it ? <|endoftext|> Great . I got to try so many things for the first time . <|endoftext|> Like what ? <|endoftext|> I went sailing , fishing , and horseback riding . <|endoftext|> I ’ m so jealous . <|endoftext|>
# Diana , do you like the perfume I gave you ? <|endoftext|> It ’ s good . But to tell you the truth , I don ’ t wear perfume . <|endoftext|> I ’ m sorry . I didn ’ t know that . <|endoftext|>
# Ah , ah , ah ... <|endoftext|> All right , Bill.Here ' s your daily exercise schedule . You are to jog before breakfast . <|endoftext|> Jog ? <|endoftext|> Then , you are to walk to work . <|endoftext|> Walk ? <|endoftext|> Thirty minutes in gym at lunch time . <|endoftext|> Oh no . <|endoftext|> Use the stairs , never the elevator . <|endoftext|> Oh , dear . <|endoftext|> And three times a week , you can either swim , play racketball , or hand ball . <|endoftext|> Oh no . <|endoftext|> OK , you can stop now.It ' s time for the dance class . <|endoftext|> Dance class ! I don't know how . <|endoftext|> You will . <|endoftext|>
#  77%|███████▋  | 17/22 [00:01<00:00,  8.69it/s]
# Hi Bill , I saw your grandma yesterday . <|endoftext|> Oh where was that ? <|endoftext|> I was running around the track at my college and there she was walking around the same track . <|endoftext|> Grannie always tries to stay fit and healthy.She is always making us kids eat the proper foods . <|endoftext|> Well , it pays off for her.How old is she anyway ? <|endoftext|> She will be 86 next month . <|endoftext|>
# I would like to register for a class today . <|endoftext|> No problem , what class would you like to take ? <|endoftext|> I would very much enjoy taking a Psychology class.Because I'm crazy . <|endoftext|> There are two classes that are still open . <|endoftext|> Which days are these classes on ? <|endoftext|> The first class is a Tuesday and Thursday class from two to three . <|endoftext|> What about the other class ? <|endoftext|> The other class is on Monday and Wednesday from 10 am - 12 . <|endoftext|> Are you sure there are no more open classes ? <|endoftext|> I'm positive . <|endoftext|> Sign me up for Monday and Wednesday . <|endoftext|>
# Dad , why are you taping the windows ? <|endoftext|> Honey , a typhoon is coming . <|endoftext|> Really ? Wow , I don't have to go to school tomorrow . <|endoftext|> Jenny , come and help , we need to prepare more food . <|endoftext|>
# Hi , my name is Lean , and I'm from Russia . <|endoftext|> Nice to meet you , Lean . My name is Alike . I'm from Japan . <|endoftext|> To me English is a difficult language . <|endoftext|> A second language is always difficult . <|endoftext|> True , but English is harder than most . It's a crazy language . <|endoftext|> A crazy language ? Why do you say that ? <|endoftext|> One letter can have several pronunciations and one word can have several meanings . <|endoftext|>
#  95%|█████████▌| 21/22 [00:02<00:00, 10.01it/s]
# Can I help you ? <|endoftext|> I hope so . I'm looking for some material for a paper I'm writing , and I'm not quite sure where to look . <|endoftext|> I'll certainly try to help you . What topic is your paper on ? <|endoftext|> My paper is on the influence of television on children . <|endoftext|> There are several possible sources you might use for that topic . I suggest you use the computer and the computer will give you a list of every scientific journal that talks about children and television . <|endoftext|>
# Here ’ s your hot dog and beer . What happened ? Did I miss anything ? <|endoftext|> Yeah , Cal Ripen just hit a home run . <|endoftext|> What ’ s the score ? <|endoftext|> Well it was 3 to 4 , but Ripen ’ s home run made it 5 to 4 since another player was on first base . <|endoftext|> So Baltimore is winning ? <|endoftext|> Right . <|endoftext|> This is a really great place to watch a baseball game . <|endoftext|> Yeah , there isn ’ t a bad seat in the place . <|endoftext|> The fans are great here , too . Not like in Philadelphia . <|endoftext|> It was a great idea to spend a day watching a game . <|endoftext|>
# 100%|██████████| 22/22 [00:02<00:00,  9.87it/s]

# %%
f = open('runs/13/dailydialog_dataset.csv', 'a', encoding="utf-8")
writer = csv.writer(f)

for i in tqdm(range(len(dataset['train']['dialog']))):
    dialog = dataset['train']['dialog'][i]
    txt = ''
    if len(dialog) > 3:
        for j in range(3):
            txt += dialog[j] + tokenizer.eos_token
        # for u in dialog[:-1]:
        #     txt += u + tokenizer.eos_token
        writer.writerow([txt, dialog[3] + tokenizer.eos_token])

f.close()
# Out:
# 100%|██████████| 11118/11118 [16:54<00:00, 10.96it/s]

# %% [markdown]
# ## PersonaChat

# %%
dataset = load_dataset('bavard/personachat_truecased')
# Out:
# No config specified, defaulting to: personachat_truecased/full
# Reusing dataset personachat_truecased (C:\Users\stwan\.cache\huggingface\datasets\bavard___personachat_truecased\full\1.0.0\73ee8f1a0d9e42255af5a8301877a2f3ac638e55b1cd9cbccca5ab7e23d2b638)
# 100%|██████████| 2/2 [00:00<00:00, 166.75it/s]

# %%
print(dataset)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['personality', 'candidates', 'history', 'conv_id', 'utterance_idx'],
#         num_rows: 131438
#     })
#     validation: Dataset({
#         features: ['personality', 'candidates', 'history', 'conv_id', 'utterance_idx'],
#         num_rows: 7801
#     })
# })

# %%
f = open('runs/13/personachat_raw.csv', 'a', encoding="utf-8")
writer = csv.writer(f)
writer.writerow(['history', 'conv_id'])

history = dataset['train']['history']
conv_id = dataset['train']['conv_id']

for h, c in tqdm(zip(history, conv_id)):
    writer.writerow([h, c])

f.close()
# Out:
# 131438it [00:01, 131312.49it/s]

# %%
data = pd.read_csv('runs/13/personachat_raw.csv')
data
# Out:
#                                                   history  conv_id
# 0       ["Hi, how are you doing? I'm getting ready to ...        0
# 1       ["Hi, how are you doing? I'm getting ready to ...        0
# 2       ["Hi, how are you doing? I'm getting ready to ...        0
# 3       ["Hi, how are you doing? I'm getting ready to ...        0
# 4       ["Hi, how are you doing? I'm getting ready to ...        0
# ...                                                   ...      ...
# 131433  ['__ SILENCE __.', 'Hello! How are you today?'...    17877
# 131434  ['__ SILENCE __.', 'Hello! How are you today?'...    17877
# 131435  ['__ SILENCE __.', 'Hello! How are you today?'...    17877
# 131436  ['__ SILENCE __.', 'Hello! How are you today?'...    17877
# 131437  ['__ SILENCE __.', 'Hello! How are you today?'...    17877
#
# [131438 rows x 2 columns]

# %%
f = open('runs/13/personachat_dataset.csv', 'a', encoding="utf-8")
writer = csv.writer(f)
writer.writerow(['history', 'groundtruth'])

data = pd.read_csv('runs/13/personachat_raw.csv')
data['history'] = data['history'].apply(literal_eval)
for i in tqdm(range(17877)):
    txt = ''
    row = data.loc[data['conv_id'] == i].iloc[-1]['history']
    # if len(row) > 3:
    #     for u in row[:-1]:
    #         txt += u + tokenizer.eos_token
    #     writer.writerow([txt, row[-1] + tokenizer.eos_token])
    if len(row) > 3:
        for j in range(3):
            txt += row[j] + tokenizer.eos_token
        writer.writerow([txt, row[3] + tokenizer.eos_token])

f.close()
# Out:
#  14%|█▎        | 17878/131438 [00:06<00:38, 2922.73it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3740/2506030829.py in <module>
#       7 for i in tqdm(range(len(data['history']))):
#       8     txt = ''
# ----> 9     row = data.loc[data['conv_id'] == i].iloc[-1]['history']
#      10     # if len(row) > 3:
#      11     #     for u in row[:-1]:
#
# ~\anaconda3\envs\Dialect_Prompts\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\envs\Dialect_Prompts\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# ~\anaconda3\envs\Dialect_Prompts\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
#    1499         if key >= len_axis or key < -len_axis:
# -> 1500             raise IndexError("single positional indexer is out-of-bounds")
#    1501
#    1502     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
pre_data = pd.read_csv('runs/10_cornell_movie/personachat_dataset.csv')
pre_data.head()
# Out:
#                                              history  \
# 0  Hi, how are you doing? I'm getting ready to do...
# 1  Hi, how are you doing today?<|endoftext|>I am ...
# 2  We all live in a yellow submarine, a yellow su...
# 3  Hi! I work as a gourmet cook.<|endoftext|>I do...
# 4  How are you doing today.<|endoftext|>What do y...
#
#                                          groundtruth
# 0  I think I will can some jam. Do you also play ...
# 1  That's nice. Moms are pretty cool too.<|endoft...
# 2  I prefer mojitos. Watermelon or cucumber.<|end...
# 3  I work as a gourmet cook who also has a pitch ...
# 4            I watch kids for a living.<|endoftext|>

# %% [markdown]
# ## Cornell Movie

# %%
metadata = pd.read_csv('runs/10_cornell_movie/movie_conversations.txt', delimiter=" \+\+\+\$\+\+\+ ", names=['character1ID', 'character2ID', 'movieID', 'dialog'])
metadata.head()
# Out:
# C:\Users\stwan\anaconda3\envs\Dialect_Prompts\lib\site-packages\pandas\util\_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
#   character1ID character2ID movieID                            dialog
# 0           u0           u2      m0  ['L194', 'L195', 'L196', 'L197']
# 1           u0           u2      m0                  ['L198', 'L199']
# 2           u0           u2      m0  ['L200', 'L201', 'L202', 'L203']
# 3           u0           u2      m0          ['L204', 'L205', 'L206']
# 4           u0           u2      m0                  ['L207', 'L208']

# %%
dialog_data = pd.read_csv('runs/10_cornell_movie/movie_lines.txt', delimiter=' \+\+\+\$\+\+\+ ', encoding='unicode_escape', names=['lineID', 'characterID', 'movieID', 'characterName', 'dialog'])
dialog_data
# Out:
# C:\Users\stwan\anaconda3\envs\Dialect_Prompts\lib\site-packages\pandas\util\_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
#          lineID characterID movieID characterName  \
# 0         L1045          u0      m0        BIANCA
# 1         L1044          u2      m0       CAMERON
# 2          L985          u0      m0        BIANCA
# 3          L984          u2      m0       CAMERON
# 4          L925          u0      m0        BIANCA
# ...         ...         ...     ...           ...
# 304708  L666371       u9030    m616      DURNFORD
# 304709  L666370       u9034    m616       VEREKER
# 304710  L666369       u9030    m616      DURNFORD
# 304711  L666257       u9030    m616      DURNFORD
# 304712  L666256       u9034    m616       VEREKER
#
#                                                    dialog
# 0                                            They do not!
# 1                                             They do to!
# 2                                              I hope so.
# 3                                               She okay?
# 4                                               Let's go.
# ...                                                   ...
# 304708  Lord Chelmsford seems to want me to stay back ...
# 304709  I'm to take the Sikali with the main column to...
# 304710                           Your orders, Mr Vereker?
# 304711  Good ones, yes, Mr Vereker. Gentlemen who can ...
# 304712  Colonel Durnford... William Vereker. I hear yo...
#
# [304713 rows x 5 columns]

# %%
tokenizer = AutoTokenizer.from_pretrained("microsoft/DialoGPT-large")

# %%
f = open('runs/13/cornell_movie_dataset.csv', 'a', encoding="utf-8")
writer = csv.writer(f)
writer.writerow(['history', 'groundtruth'])

for i in tqdm(range(304712)):
    dialog = ''
    metainfo = metadata.iloc[i]['dialog'][1:-1].split(',')
    if len(metainfo) > 3:
        if dialog_data.loc[dialog_data['lineID'] == metainfo[0].strip()[1:-1]].iloc[0]['dialog'] != None and dialog_data.loc[dialog_data['lineID'] == metainfo[1].strip()[1:-1]].iloc[0]['dialog'] != None and dialog_data.loc[dialog_data['lineID'] == metainfo[2].strip()[1:-1]].iloc[0]['dialog'] != None and dialog_data.loc[dialog_data['lineID'] == metainfo[3].strip()[1:-1]].iloc[0]['dialog'] != None:
            for j in range(3):
                idx = metainfo[j]
                u = dialog_data.loc[dialog_data['lineID'] == idx.strip()[1:-1]].iloc[0]['dialog']
                dialog += (u + tokenizer.eos_token)
            writer.writerow([dialog, dialog_data.loc[dialog_data['lineID'] == metainfo[3].strip()[1:-1]].iloc[0]['dialog'] + tokenizer.eos_token])
            # for idx in metainfo[:-1]:
            #     u = dialog_data.loc[dialog_data['lineID'] == idx.strip()[1:-1]].iloc[0]['dialog']
            #     dialog += (u + tokenizer.eos_token)
        

f.close()
# Out:
#  27%|██▋       | 83097/304712 [3:28:18<9:15:33,  6.65it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_27656/2508241322.py in <module>
#       5 for i in tqdm(range(304712)):
#       6     dialog = ''
# ----> 7     metainfo = metadata.iloc[i]['dialog'][1:-1].split(',')
#       8     if len(metainfo) > 3:
#       9         if dialog_data.loc[dialog_data['lineID'] == metainfo[0].strip()[1:-1]].iloc[0]['dialog'] != None and dialog_data.loc[dialog_data['lineID'] == metainfo[1].strip()[1:-1]].iloc[0]['dialog'] != None and dialog_data.loc[dialog_data['lineID'] == metainfo[2].strip()[1:-1]].iloc[0]['dialog'] != None and dialog_data.loc[dialog_data['lineID'] == metainfo[3].strip()[1:-1]].iloc[0]['dialog'] != None:
#
# ~\anaconda3\envs\Dialect_Prompts\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~\anaconda3\envs\Dialect_Prompts\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1564
#    1565             # validate the location
# -> 1566             self._validate_integer(key, axis)
#    1567
#    1568             return self.obj._ixs(key, axis=axis)
#
# ~\anaconda3\envs\Dialect_Prompts\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    1498         len_axis = len(self.obj._get_axis(axis))
#    1499         if key >= len_axis or key < -len_axis:
# -> 1500             raise IndexError("single positional indexer is out-of-bounds")
#    1501
#    1502     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
movie_dataset = pd.read_csv('runs/10_cornell_movie/cornell_movie_dataset.csv')
movie_dataset.head()
# Out:
#                                              history  \
# 0  Can we make this quick?  Roxanne Korrine and A...
# 1  No, no, it's my fault -- we didn't have a prop...
# 2  C'esc ma tete. This is my head<|endoftext|>Rig...
# 3  She's not a...<|endoftext|>Lesbian?  No. I fou...
# 4  Well, no...<|endoftext|>Then that's all you ha...
#
#                                          groundtruth
# 0  Okay... then how 'bout we try out some French ...
# 1  Seems like she could get a date easy enough......
# 2                        Forget French.<|endoftext|>
# 3  Who knows?  All I've ever heard her say is tha...
# 4         You always been this selfish?<|endoftext|>

# %% [markdown]
# ## Replace html

# %%
def replace_html(s):
    s = re.sub(r'<a href=.*?<mark>', '', s)
    return re.sub(r'</mark></a>', ' ', s)

# %%
df = pd.read_csv('runs/13/orig/cornell_movie_dataset_aave.csv')
df.head()
# Out:
#                                              history  \
# 0  Can we make this quick?  Roxanne Korrine and A...
# 1  No, no, it's my fault -- we ain't have a prope...
# 2  C'esc ma tete. This my head<|endoftext|>Right....
# 3  Sheain't a...<|endoftext|>Lesbian?  don't no. ...
# 4  Well, no...<|endoftext|>Then that's all you ha...
#
#                                          groundtruth  \
# 0  Okay... then how 'bout we try out some French ...
# 1  Seem like she could get a date easy enough...<...
# 2  That's because it's such a nice one.<|endoftext|>
# 3  Who know?  All I've ever heard her say is that...
# 4         You always been this selfish?<|endoftext|>
#
#                                         history_html  \
# 0  Can we make this quick?  Roxanne Korrine and A...
# 1  No, no, it's my fault -- we didn't have a prop...
# 2  C'esc ma tete. This <a href='drop_aux' title='...
# 3  She<a href='negative_concord' title='1'><mark>...
# 4  Well, no...<|endoftext|>Then that's all you ha...
#
#                                     groundtruth_html
# 0  Okay... then how 'bout we try out some French ...
# 1  <a href='uninflect' title='1'><mark>Seems</mar...
# 2  That's because it's such a nice one.<|endoftext|>
# 3  Who <a href='uninflect' title='1'><mark>knows<...
# 4         You always been this selfish?<|endoftext|>

# %%
df['history_aave'] = df['history_html'].apply(replace_html)
df['groundtruth_aave'] = df['groundtruth_html'].apply(replace_html)
df.head()
# Out:
#                                              history  \
# 0  Can we make this quick?  Roxanne Korrine and A...
# 1  No, no, it's my fault -- we ain't have a prope...
# 2  C'esc ma tete. This my head<|endoftext|>Right....
# 3  Sheain't a...<|endoftext|>Lesbian?  don't no. ...
# 4  Well, no...<|endoftext|>Then that's all you ha...
#
#                                          groundtruth  \
# 0  Okay... then how 'bout we try out some French ...
# 1  Seem like she could get a date easy enough...<...
# 2  That's because it's such a nice one.<|endoftext|>
# 3  Who know?  All I've ever heard her say is that...
# 4         You always been this selfish?<|endoftext|>
#
#                                         history_html  \
# 0  Can we make this quick?  Roxanne Korrine and A...
# 1  No, no, it's my fault -- we didn't have a prop...
# 2  C'esc ma tete. This <a href='drop_aux' title='...
# 3  She<a href='negative_concord' title='1'><mark>...
# 4  Well, no...<|endoftext|>Then that's all you ha...
#
#                                     groundtruth_html  \
# 0  Okay... then how 'bout we try out some French ...
# 1  <a href='uninflect' title='1'><mark>Seems</mar...
# 2  That's because it's such a nice one.<|endoftext|>
# 3  Who <a href='uninflect' title='1'><mark>knows<...
# 4         You always been this selfish?<|endoftext|>
#
#                                         history_aave  \
# 0  Can we make this quick?  Roxanne Korrine and A...
# 1  No, no, it's my fault -- we didn't have a prop...
# 2  C'esc ma tete. This is my head<|endoftext|>Rig...
# 3  She's  not a...<|endoftext|>Lesbian?  No . I f...
# 4  Well, no...<|endoftext|>Then that's all you ha...
#
#                                     groundtruth_aave
# 0  Okay... then how 'bout we try out some French ...
# 1  Seems  like she could get a date easy enough.....
# 2  That's because it's such a nice one.<|endoftext|>
# 3  Who knows ?  All I've ever heard her say is th...
# 4         You always been this selfish?<|endoftext|>

# %%
df.to_csv('runs/13/orig/cornell_movie_dataset_full.csv', index=False)

# %%
df = pd.read_csv('runs/13/orig/dailydialog_dataset_aave.csv')
df['history_aave'] = df['history_html'].apply(replace_html)
df['groundtruth_aave'] = df['groundtruth_html'].apply(replace_html)
df.to_csv('runs/13/orig/dailydialog_dataset_full.csv', index=False)

# %%
df = pd.read_csv('runs/13/orig/personachat_dataset_aave.csv')
df['history_aave'] = df['history_html'].apply(replace_html)
df['groundtruth_aave'] = df['groundtruth_html'].apply(replace_html)
df.to_csv('runs/13/orig/personachat_dataset_full.csv', index=False)

# %% [markdown]
# ## DialoGPT -> BST

# %%
tokenizer = BlenderbotTokenizer.from_pretrained("facebook/blenderbot-1B-distill")
def to_bst(s):
    s = s.replace('<|endoftext|>', tokenizer.eos_token + tokenizer.bos_token)
    return s[:-len(tokenizer.bos_token)]

# %%
df = pd.read_csv('runs/21/dataset/dialogpt/all/cornell_movie_dataset_all.csv')
df
# Out:
#                                                  history  \
# 0      Can we make this quick?  Roxanne Korrine and A...
# 1      No, no, it's my fault -- we didn't have a prop...
# 2      C'esc ma tete. This is my head<|endoftext|>Rig...
# 3      She's not a...<|endoftext|>Lesbian?  No. I fou...
# 4      Well, no...<|endoftext|>Then that's all you ha...
# ...                                                  ...
# 27412  Where are we going?<|endoftext|>To find Rogue....
# 27413  You designed this yourself?<|endoftext|>Actual...
# 27414  Why is everybody up at sunrise?<|endoftext|>Th...
# 27415  Is that what you're looking for?<|endoftext|>A...
# 27416  I'll never understand your regard for them, Ch...
#
#                                              groundtruth  \
# 0      Okay... then how 'bout we try out some French ...
# 1      Seems like she could get a date easy enough......
# 2      That's because it's such a nice one.<|endoftext|>
# 3      Who knows?  All I've ever heard her say is tha...
# 4             You always been this selfish?<|endoftext|>
# ...                                                  ...
# 27412  The brainwaves of mutants are quite different ...
# 27413  We were friends once...  But that was a long t...
# 27414  She borrowed your power to save her life.  Whe...
# 27415                    Enough for a test.<|endoftext|>
# 27416        Not at the cost of lives, Max.<|endoftext|>
#
#                                             history_aave  \
# 0      Can we make this quick?  Roxanne Korrine and A...
# 1      No, no, it's my fault -- we ain't have a prope...
# 2      C'esc ma tete. dis my head<|endoftext|>rite.  ...
# 3      Sheain't a...<|endoftext|>Lesbian?  don't no. ...
# 4      Well, no...<|endoftext|>Then dat's all you had...
# ...                                                  ...
# 27412  Where are we going?<|endoftext|>To find Rogue....
# 27413  Yu done designed dis yourself?<|endoftext|>Act...
# 27414  Why everybody up at sunrise?<|endoftext|>da su...
# 27415  Is that wat u're lookin fa?<|endoftext|>A piec...
# 27416  I'll never understand ur regard for them, Char...
#
#                                             history_html  num_aave_fts  \
# 0      Can we make this quick?  Roxanne Korrine and A...             1
# 1      No, no, it's my fault -- we didn't have a prop...             0
# 2      C'esc ma tete. This <a href='drop_aux' title='...             2
# 3      She<a href='negative_concord' title='1'><mark>...             4
# 4      Well, no...<|endoftext|>Then that's all you ha...             0
# ...                                                  ...           ...
# 27412  Where are we going?<|endoftext|>To find Rogue....             0
# 27413  You<a href='been_done' title='1'><mark></mark>...             1
# 27414  Why <a href='drop_aux' title='1'><mark>is</mar...             2
# 27415  Is that what you're looking for?<|endoftext|>A...             0
# 27416  I'll never understand your regard for them, Ch...             0
#
#                                         groundtruth_aave
# 0      Ite... then how 'bout we try outt some French ...
# 1      Seem like she could get a date easy enough...<...
# 2        That's becuz it's such a nice one.<|endoftext|>
# 3      Who knoe?  alll I've eva heard her say is that...
# 4              You always been dis selfish?<|endoftext|>
# ...                                                  ...
# 27412  The brainwaves of mutants quite diffrent than ...
# 27413  We was frens once...  But that was a long time...
# 27414  She borrowed ur power to save her life.  When ...
# 27415                    Enough for a test.<|endoftext|>
# 27416        Not at the cost of lives, Max.<|endoftext|>
#
# [27417 rows x 6 columns]

# %%
file_path = 'runs/21/dataset/dialogpt/morp/dailydialog_dataset_morp.csv'
df = pd.read_csv(file_path)
df['history'] = df['history'].apply(to_bst)
df['history_aave'] = df['history_aave'].apply(to_bst)
df.to_csv('runs/21/dataset/bst/morp/dailydialog_dataset_morp.csv', index=False)

# %% [markdown]
# ## Length Control

# %% [markdown]
# ### fit the models

# %% [markdown]
# #### bst

# %%
file_path = 'runs/21/dataset/bst/all/dailydialog_dataset_all.csv'

tokenizer = BlenderbotTokenizer.from_pretrained("facebook/blenderbot-1B-distill")
df = pd.read_csv(file_path)
drop_idx = []
for i, (chat, chat_aave) in tqdm(enumerate(zip(df['history'], df['history_aave']))):
  chat_history_ids = tokenizer.encode(chat, return_tensors='pt').to(device=device)
  chat_history_aave_ids = tokenizer.encode(chat_aave, return_tensors='pt').to(device=device)
  if chat_history_aave_ids.shape[1] > 90 or chat_history_ids.shape[1] > 90:
    drop_idx.append(i)
# Out:
# 1it [00:04,  4.86s/it]Token indices sequence length is longer than the specified maximum sequence length for this model (169 > 128). Running this sequence through the model will result in indexing errors
# 10249it [00:12, 794.71it/s]

# %%
len(drop_idx)
# Out:
# 857

# %%
file_path = 'runs/21/dataset/bst/morp/dailydialog_dataset_morp.csv'
df = pd.read_csv(file_path)
df = df.drop(drop_idx)
df.to_csv(file_path, index=False)

# %% [markdown]
# #### dialogpt

# %%
file_path = 'runs/21/dataset/dialogpt/all/cornell_movie_dataset_all.csv'

tokenizer = AutoTokenizer.from_pretrained("microsoft/DialoGPT-large")
df = pd.read_csv(file_path)
drop_idx = []
for i in tqdm(range(len(df['history']))):
    chat_history_sae_ids = tokenizer.encode(df.iloc[i]['history'], return_tensors='pt').to(device=device)
    chat_history_aave_ids = tokenizer.encode(df.iloc[i]['history_aave'], return_tensors='pt').to(device=device)
    if chat_history_sae_ids.shape[1] >= 1000 or chat_history_aave_ids.shape[1] >= 1000:
        drop_idx.append(i)
# Out:
# 100%|██████████| 27417/27417 [00:19<00:00, 1418.65it/s]

# %% [markdown]
# ### up to n turns

# %%
def find_nth_occur(string, n):
    for i, match in enumerate(re.finditer('\<\|endoftext\|\>', string)):
        if (i == n - 1):
            return match.end()

# %%
df = pd.read_csv('runs/13/orig/cornell_movie_dataset_full.csv')

# %%
idx = []
for i, (sae, aave) in enumerate(zip(df['history'], df['history_aave'])):
    if sae.count('<|endoftext|>') > 3:
        idx.append(i)

for i in idx:
    sae = df.iloc[i]['history']
    third_occur = find_nth_occur(sae, 3)
    fourth_occur = find_nth_occur(sae, 4)
    df.iloc[i]['groundtruth'] = sae[third_occur: fourth_occur]
    df.iloc[i]['history'] = sae[:third_occur]

    aave = df.iloc[i]['history_aave']
    third_occur = find_nth_occur(aave, 3)
    fourth_occur = find_nth_occur(aave, 4)
    df.iloc[i]['groundtruth_aave'] = aave[third_occur: fourth_occur]
    df.iloc[i]['history_aave'] = aave[:third_occur]

# %%
df.to_csv('runs/13/orig/cornell_movie_dataset_short.csv', index=False)

# %% [markdown]
# ## AAVE Density Control

# %%
def count_aave_features(s):
    return len(re.findall(r'<a href=.*?<mark>', s))

# %%
df = pd.read_csv('runs/13/orig/cornell_movie_dataset_short.csv')
# df = pd.read_csv('runs/13/orig/personachat_dataset_short.csv')
# df = pd.read_csv('runs/13/orig/dailydialog_dataset_short.csv')

drop_idx = []
for i, txt in enumerate(df['history_html']):
    if count_aave_features(txt) <= 2:
        drop_idx.append(i)
df = df.drop(drop_idx)

# df.to_csv('runs/16/orig/cornell_movie_dataset_4fts.csv', index=False)
# df.to_csv('runs/16/orig/personachat_dataset_4fts.csv', index=False)
# df.to_csv('runs/16/orig/dailydialog_dataset_4fts.csv', index=False)

df
# Out:
#                                                  history  \
# 3      Sheain't a...<|endoftext|>Lesbian?  don't no. ...
# 7      Oh my God, this mean you're becoming normal?<|...
# 8      Listen, I know you hate having to sit home bec...
# 13     Now don't get upset. Daddy, but it's this boy....
# 21     What make you think he'll do it?<|endoftext|>H...
# ...                                                  ...
# 27376  You know what a wire transfer is?<|endoftext|>...
# 27379  Who are you?<|endoftext|>We done hung out last...
# 27395  My name Slovo, Czech secret police. When you h...
# 27399  To us it mean no walls, no speed limits, no ja...
# 27403  Correct...  Apparently, Adamantium the only me...
#
#                                              groundtruth  \
# 3      Who know?  All I've ever heard her say is that...
# 7                        What do you think?<|endoftext|>
# 8      I wish I had that luxury. I'm the only sophomo...
# 13     Then neither will you.  And I'll get to sleep ...
# 21     They always let felons sit in on Honors Biolog...
# ...                                                  ...
# 27376  Sure. Just chisel some off your heart.<|endoft...
# 27379  Hey, take it easy. I'm just a dude tryna make ...
# 27395  First of all, you should kill whoever sold you...
# 27399  How you gonna do that with government and rule...
# 27403  So where you think he's planning this larger d...
#
#                                             history_html  \
# 3      She<a href='negative_concord' title='1'><mark>...
# 7      Oh my God, <a href='drop_aux' title='1'><mark>...
# 8      Listen, I know you hate having to sit home bec...
# 13     Now don't get upset. Daddy, but <a href='dey/i...
# 21     What <a href='uninflect' title='1'><mark>makes...
# ...                                                  ...
# 27376  <a href='drop_aux' title='1'><mark>Do</mark></...
# 27379  Who are you?<|endoftext|>We<a href='been_done'...
# 27395  My name <a href='drop_aux' title='1'><mark>is<...
# 27399  To us it <a href='uninflect' title='1'><mark>m...
# 27403  Correct...  Apparently, Adamantium <a href='dr...
#
#                                         groundtruth_html  \
# 3      Who <a href='uninflect' title='1'><mark>knows<...
# 7                        What do you think?<|endoftext|>
# 8      I wish I had that luxury. I'm the only sophomo...
# 13     Then neither will you.  And I'll get to sleep ...
# 21     They always let felons sit in on Honors Biolog...
# ...                                                  ...
# 27376  Sure. Just chisel some off your heart.<|endoft...
# 27379  Hey, take it easy. I'm just a dude trying to m...
# 27395  First of all, you should kill whoever sold you...
# 27399  How you gonna do that with government and <a h...
# 27403  So where <a href='drop_aux' title='1'><mark>do...
#
#                                             history_aave  \
# 3      She's  not a...<|endoftext|>Lesbian?  No . I f...
# 7      Oh my God, does this mean you're becoming norm...
# 8      Listen, I know you hate having to sit home bec...
# 13     Now don't get upset. Daddy, but there 's this ...
# 21     What makes  you think he'll do it?<|endoftext|...
# ...                                                  ...
# 27376  Do you know what a wire transfer is?<|endoftex...
# 27379  Who are you?<|endoftext|>We  hung out last nig...
# 27395  My name is Slovo, Czech secret police. When yo...
# 27399  To us it means  no walls, no speed limits, no ...
# 27403  Correct...  Apparently, Adamantium is the only...
#
#                                         groundtruth_aave
# 3      Who knows ?  All I've ever heard her say is th...
# 7                        What do you think?<|endoftext|>
# 8      I wish I had that luxury. I'm the only sophomo...
# 13     Then neither will you.  And I'll get to sleep ...
# 21     They always let felons sit in on Honors Biolog...
# ...                                                  ...
# 27376  Sure. Just chisel some off your heart.<|endoft...
# 27379  Hey, take it easy. I'm just a dude trying to m...
# 27395  First of all, you should kill whoever sold you...
# 27399  How you gonna do that with government and rule...
# 27403  So where do you think he's planning this large...
#
# [5798 rows x 6 columns]

# %%
new_df = pd.read_csv('runs/16/orig/personachat_dataset_4fts.csv')
new_df
# Out:
#                                                history  \
# 0    Hello do u like animals I got a kitten named L...
# 1    Hello there. How you? I got off from creating ...
# 2    Hi anybody there? Ding dong!<|endoftext|>The w...
# 3    Hi! I am tryna design a new app to get people ...
# 4    How are you doing today?<|endoftext|>Great! Ju...
# ..                                                 ...
# 436  __ SILENCE __.<|endoftext|>Hi, I am a big viki...
# 437  __ SILENCE __.<|endoftext|>Hi. Iain't much for...
# 438  __ SILENCE __.<|endoftext|>My name mark and I ...
# 439  __ SILENCE __.<|endoftext|>Hi, I was born in F...
# 440  __ SILENCE __.<|endoftext|>Hi! running and gam...
#
#                                            groundtruth  \
# 0    Oh wow, that sound interesting. Are you really...
# 1    I am studying for my masters. Fortunately mom ...
# 2    I love going shopping when I ain't knitting.<|...
# 3    I think it is an important thing to consider, ...
# 4    Dialectical behavioral therapy. I use it to he...
# ..                                                 ...
# 436  If you ain't no viking, what you? It cold in m...
# 437  That sound fun. I hope you meant it. I am a li...
# 438  I do not know no days I feel like it but I do ...
# 439  Interesting. I've a large family still live in...
# 440  I am jealous! I am employed in an office. Woul...
#
#                                           history_html  \
# 0    Hello do u like animals I <a href='got' title=...
# 1    Hello there. How <a href='drop_aux' title='1'>...
# 2    Hi anybody there? Ding dong!<|endoftext|>The w...
# 3    Hi! I am trying to design a new app to get peo...
# 4    How are you doing today?<|endoftext|>Great! Ju...
# ..                                                 ...
# 436  __ SILENCE __.<|endoftext|>Hi, I am a big viki...
# 437  __ SILENCE __.<|endoftext|>Hi. I<a href='negat...
# 438  __ SILENCE __.<|endoftext|>My name <a href='dr...
# 439  __ SILENCE __.<|endoftext|>Hi, I was born in F...
# 440  __ SILENCE __.<|endoftext|>Hi! running and gam...
#
#                                       groundtruth_html  \
# 0    Oh wow, that <a href='uninflect' title='1'><ma...
# 1    I am studying for my masters. Fortunately mom ...
# 2    I love going shopping when I <a href='negative...
# 3    I think it is an important thing to consider, ...
# 4    Dialectical behavioral therapy. I use it to he...
# ..                                                 ...
# 436  If you <a href='negative_concord' title='1'><m...
# 437  That <a href='uninflect' title='1'><mark>sound...
# 438  I do not know <a href='None' title='1'><mark>s...
# 439  Interesting. I've a large family <a href='null...
# 440  I am jealous! I am employed in an office. Woul...
#
#                                           history_aave  \
# 0    Hello do u like animals I have  a kitten named...
# 1    Hello there. How are you? I got off from creat...
# 2    Hi anybody there? Ding dong!<|endoftext|>The w...
# 3    Hi! I am trying to design a new app to get peo...
# 4    How are you doing today?<|endoftext|>Great! Ju...
# ..                                                 ...
# 436  __ SILENCE __.<|endoftext|>Hi, I am a big viki...
# 437  __ SILENCE __.<|endoftext|>Hi. I'm  not much f...
# 438  __ SILENCE __.<|endoftext|>My name is mark and...
# 439  __ SILENCE __.<|endoftext|>Hi, I was born in F...
# 440  __ SILENCE __.<|endoftext|>Hi! running and gam...
#
#                                       groundtruth_aave
# 0    Oh wow, that sounds  interesting. Are you real...
# 1    I am studying for my masters. Fortunately mom ...
# 2    I love going shopping when I am  not knitting....
# 3    I think it is an important thing to consider, ...
# 4    Dialectical behavioral therapy. I use it to he...
# ..                                                 ...
# 436  If you are  not a viking , what are you? It is...
# 437  That sounds  fun. I hope you meant it. I am a ...
# 438  I do not know some days  I feel like it but I ...
# 439  Interesting. I've a large family that still li...
# 440  I am jealous! I am employed in an office. Woul...
#
# [441 rows x 6 columns]

# %% [markdown]
# ## Stats

# %%
df = pd.read_csv('runs/16/orig/cornell_movie_dataset_4fts.csv')
df
# Out:
#                                                 history  \
# 0     What make you think he'll do it?<|endoftext|>H...
# 1     You been got it, Verona.  I pick up the tab, y...
# 2     So he got this huge raging fit about Sarah Law...
# 3     Katarina Stratford.  My, my.  You've been terr...
# 4     How far from here?<|endoftext|>I ain't no seam...
# ...                                                 ...
# 1778  I know, I know, it's just -- he's back on the ...
# 1779  Sphinx brand.  When I got out of weapons desig...
# 1780  You've really got me confused, Cage. On the on...
# 1781  To us it mean no walls, no speed limits, no ja...
# 1782  Correct...  Apparently, Adamantium the only me...
#
#                                             groundtruth  \
# 0     They always let felons sit in on Honors Biolog...
# 1                                How much?<|endoftext|>
# 2              That's never ain't no proven<|endoftext|
# 3     I still maintain that he kicked himself in the...
# 4     I am afraid this ain't the worst news.<|endoft...
# ...                                                 ...
# 1778  If he come here, I'll handle him.  Remember --...
# 1779      Oh sweetheart, just a quick one.<|endoftext|>
# 1780  Iain't interested. I've already got a job.<|en...
# 1781  How you gonna do that with government and rule...
# 1782  So where you think he's planning this larger d...
#
#                                            history_html  \
# 0     What <a href='uninflect' title='1'><mark>makes...
# 1     You<a href='been_done' title='1'><mark></mark>...
# 2     So he <a href='got' title='1'><mark>has</mark>...
# 3     Katarina Stratford.  My, my.  You've been terr...
# 4     How far from here?<|endoftext|>I <a href='nega...
# ...                                                 ...
# 1778  I know, I know, it's just -- he's back on the ...
# 1779  Sphinx brand.  When I got out of weapons desig...
# 1780  You've really got me confused, Cage. On the on...
# 1781  To us it <a href='uninflect' title='1'><mark>m...
# 1782  Correct...  Apparently, Adamantium <a href='dr...
#
#                                        groundtruth_html  \
# 0     They always let felons sit in on Honors Biolog...
# 1                                How much?<|endoftext|>
# 2     That's <a href='negative_concord' title='1'><m...
# 3     I still maintain that he kicked himself in the...
# 4     I am afraid this <a href='negative_concord' ti...
# ...                                                 ...
# 1778  If he <a href='uninflect' title='1'><mark>come...
# 1779      Oh sweetheart, just a quick one.<|endoftext|>
# 1780  I<a href='negative_concord' title='1'><mark>'m...
# 1781  How you gonna do that with government and <a h...
# 1782  So where <a href='drop_aux' title='1'><mark>do...
#
#                                            history_aave  \
# 0     What makes  you think he'll do it?<|endoftext|...
# 1     You  got it, Verona.  I pick up the tab, you d...
# 2     So he has  this huge raging fit about Sarah La...
# 3     Katarina Stratford.  My, my.  You've been terr...
# 4     How far from here?<|endoftext|>I am  not a sea...
# ...                                                 ...
# 1778  I know, I know, it's just -- he's back on the ...
# 1779  Sphinx brand.  When I got out of weapons desig...
# 1780  You've really got me confused, Cage. On the on...
# 1781  To us it means  no walls, no speed limits, no ...
# 1782  Correct...  Apparently, Adamantium is the only...
#
#                                        groundtruth_aave
# 0     They always let felons sit in on Honors Biolog...
# 1                                How much?<|endoftext|>
# 2               That's never  been  proven<|endoftext|
# 3     I still maintain that he kicked himself in the...
# 4     I am afraid this is  not the worst news.<|endo...
# ...                                                 ...
# 1778  If he comes  here, I'll handle him.  Remember ...
# 1779      Oh sweetheart, just a quick one.<|endoftext|>
# 1780  I'm  not interested. I've already got a job.<|...
# 1781  How you gonna do that with government and rule...
# 1782  So where do you think he's planning this large...
#
# [1783 rows x 6 columns]

# %%
length = 0
length_aave = 0
for i in tqdm(range(df.shape[0])):
    row = df.iloc[i]
    length += len(tokenizer.tokenize(row['history'])) + len(tokenizer.tokenize(row['groundtruth']))
    length_aave += len(tokenizer.tokenize(row['history_aave'])) + len(tokenizer.tokenize(row['groundtruth_aave']))
print(length / df.shape[0])
print(length_aave / df.shape[0])
# Out:
#  58%|█████▊    | 1026/1783 [00:00<00:00, 1144.92it/s]Token indices sequence length is longer than the specified maximum sequence length for this model (1266 > 1024). Running this sequence through the model will result in indexing errors
# 100%|██████████| 1783/1783 [00:01<00:00, 1111.59it/s]
# 112.53112731351655
# 117.33482893998878
